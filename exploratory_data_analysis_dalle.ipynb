# %% [markdown]
# # Exploratory Data Analysis - DALL-E Recognition Dataset

# %%
from utils import plot_images, load_images, image_stats, pixel_intensity, plot_augmented_image

# %% [markdown]
# ## Loading images

# %%
fake_train_dir = './datasets/Dalle recognition/train/fake'
real_train_dir = './datasets/Dalle recognition/train/real'
fake_test_dir = './datasets/Dalle recognition/test/fake'
real_test_dir = './datasets/Dalle recognition/test/real'

# %%
fake_train_images = load_images(fake_train_dir, 10)
real_train_images = load_images(real_train_dir, 10)
fake_test_images = load_images(fake_test_dir, 10)
real_test_images = load_images(real_test_dir, 10)

# %% [markdown]
# ## Visualizing images

# %%
plot_images(fake_test_images, 'Fake test images')
plot_images(real_test_images, 'Real test images')
plot_images(fake_train_images, 'Fake train images')
plot_images(real_train_images, 'Real train images')

# %% [markdown]
# ## Statistical summary of images

# %%
image_stats(fake_test_images)
image_stats(real_test_images)
image_stats(fake_train_images)
image_stats(real_train_images)
# Out:
# Consistent image size: (224, 224)
# Color channel modes: Counter({'RGB': 5})
# Varying image sizes: {(1294, 2000), (522, 750), (2048, 2492), (2000, 1242), (1059, 1412)}
# Color channel modes: Counter({'RGB': 3, 'RGBA': 2})
# Consistent image size: (224, 224)
# Color channel modes: Counter({'RGB': 5})
# Varying image sizes: {(1778, 2047), (800, 1276), (224, 224), (1440, 1441), (600, 400)}
# Color channel modes: Counter({'RGB': 5})

# %% [markdown]
# ## Pixel intensity analysis

# %%
pixel_intensity(fake_test_images, title="Fake test images")
pixel_intensity(real_test_images, title="Real test images")
pixel_intensity(fake_train_images, title="Fake train images")
pixel_intensity(real_train_images, title="Real train images")

# %% [markdown]
# ## Image Augmentation

# %%
plot_augmented_image(fake_test_images[1])
