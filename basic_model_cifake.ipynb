# %% [markdown]
# # Basic Model | CIFAKE

# %%
from keras.layers import Convolution2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense, Dropout
from utils import (
    build_sequential_model,
    load_augmented_data,
    plot_performance_curves,
    save_model_history,
    load_model_history,
)
import PIL

PIL.Image.MAX_IMAGE_PIXELS = None

# %%
model_name = "basic_tanh_model_cifake"
dataset_base_path = "./datasets/CIFAKE"

# Forcefully train the model
force_model_train = False

# Don't save the model
no_save = False

# %%
# Load saved model and its history
model_history_loaded, classifier, history = load_model_history(model_name)
# Out:
# Model/history not found.

# %%
# Building model
if not model_history_loaded:
    classifier = build_sequential_model(
        layers=[
            Convolution2D(100, (3, 3), activation="tanh", input_shape=(32, 32, 3)),
            MaxPooling2D(2, 2),
            Convolution2D(100, (3, 3), activation="tanh"),
            MaxPooling2D(2, 2),
            Flatten(),
            Dropout(0.5),
            Dense(50, activation="tanh"),
            Dense(2, activation="softmax"),
        ]
    )

# %%
# Model summary
classifier.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 30, 30, 100)       2800
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 100)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 100)       90100
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 100)        0
#  2D)
#
#  flatten (Flatten)           (None, 3600)              0
#
#  dropout (Dropout)           (None, 3600)              0
#
#  dense (Dense)               (None, 50)                180050
#
#  dense_1 (Dense)             (None, 2)                 102
#
# =================================================================
# Total params: 273,052
# Trainable params: 273,052
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Load augmented image generators
train_generator, validation_generator = load_augmented_data(dataset_base_path)
# Out:
# Found 100000 images belonging to 2 classes.
# Found 20000 images belonging to 2 classes.

# %%
# Train model
if not model_history_loaded or force_model_train:
    history = classifier.fit(
        train_generator,
        epochs=100,
        validation_data=validation_generator,
    )
    history = history.history
# Out:
# Epoch 1/100
# 10000/10000 [==============================] - 870s 86ms/step - loss: 0.6141 - accuracy: 0.6614 - val_loss: 0.5426 - val_accuracy: 0.7306
# Epoch 2/100
# 10000/10000 [==============================] - 87s 9ms/step - loss: 0.5803 - accuracy: 0.6953 - val_loss: 0.5297 - val_accuracy: 0.7472
# Epoch 3/100
# 10000/10000 [==============================] - 117s 12ms/step - loss: 0.5467 - accuracy: 0.7242 - val_loss: 0.4798 - val_accuracy: 0.7663
# Epoch 4/100
# 10000/10000 [==============================] - 668s 67ms/step - loss: 0.5227 - accuracy: 0.7409 - val_loss: 0.5339 - val_accuracy: 0.7585
# Epoch 5/100
# 10000/10000 [==============================] - 216s 22ms/step - loss: 0.5088 - accuracy: 0.7521 - val_loss: 0.4551 - val_accuracy: 0.7867
# Epoch 6/100
# 10000/10000 [==============================] - 69s 7ms/step - loss: 0.4943 - accuracy: 0.7631 - val_loss: 0.5831 - val_accuracy: 0.7289
# Epoch 7/100
# 10000/10000 [==============================] - 71s 7ms/step - loss: 0.4863 - accuracy: 0.7671 - val_loss: 0.5680 - val_accuracy: 0.7078
# Epoch 8/100
# 10000/10000 [==============================] - 69s 7ms/step - loss: 0.4794 - accuracy: 0.7714 - val_loss: 0.4721 - val_accuracy: 0.7907
# Epoch 9/100
# 10000/10000 [==============================] - 70s 7ms/step - loss: 0.4659 - accuracy: 0.7806 - val_loss: 0.4834 - val_accuracy: 0.7761
# Epoch 10/100
# 10000/10000 [==============================] - 68s 7ms/step - loss: 0.4674 - accuracy: 0.7780 - val_loss: 0.5827 - val_accuracy: 0.7179
# Epoch 11/100
# 10000/10000 [==============================] - 70s 7ms/step - loss: 0.4534 - accuracy: 0.7872 - val_loss: 0.4449 - val_accuracy: 0.7892
# Epoch 12/100
# 10000/10000 [==============================] - 71s 7ms/step - loss: 0.4535 - accuracy: 0.7886 - val_loss: 0.4410 - val_accuracy: 0.8016
# Epoch 13/100
# 10000/10000 [==============================] - 115s 11ms/step - loss: 0.4425 - accuracy: 0.7939 - val_loss: 0.5520 - val_accuracy: 0.7343
# Epoch 14/100
# 10000/10000 [==============================] - 104s 10ms/step - loss: 0.4498 - accuracy: 0.7900 - val_loss: 0.4281 - val_accuracy: 0.8029
# Epoch 15/100
# 10000/10000 [==============================] - 72s 7ms/step - loss: 0.4484 - accuracy: 0.7915 - val_loss: 0.5256 - val_accuracy: 0.7649
# Epoch 16/100
# 10000/10000 [==============================] - 73s 7ms/step - loss: 0.4429 - accuracy: 0.7939 - val_loss: 0.4235 - val_accuracy: 0.8056
# Epoch 17/100
# 10000/10000 [==============================] - 72s 7ms/step - loss: 0.4479 - accuracy: 0.7918 - val_loss: 0.4174 - val_accuracy: 0.8078
# Epoch 18/100
# 10000/10000 [==============================] - 75s 7ms/step - loss: 0.4326 - accuracy: 0.8023 - val_loss: 0.4459 - val_accuracy: 0.7978
# Epoch 19/100
# 10000/10000 [==============================] - 76s 8ms/step - loss: 0.4340 - accuracy: 0.7991 - val_loss: 0.4922 - val_accuracy: 0.7656
# Epoch 20/100
# 10000/10000 [==============================] - 75s 8ms/step - loss: 0.4329 - accuracy: 0.8002 - val_loss: 0.4836 - val_accuracy: 0.7814
# Epoch 21/100
# 10000/10000 [==============================] - 76s 8ms/step - loss: 0.4341 - accuracy: 0.8001 - val_loss: 0.4429 - val_accuracy: 0.7965
# Epoch 22/100
# 10000/10000 [==============================] - 74s 7ms/step - loss: 0.4310 - accuracy: 0.8018 - val_loss: 0.4404 - val_accuracy: 0.7881
# Epoch 23/100
# 10000/10000 [==============================] - 75s 8ms/step - loss: 0.4271 - accuracy: 0.8044 - val_loss: 0.4375 - val_accuracy: 0.8091
# Epoch 24/100
# 10000/10000 [==============================] - 75s 7ms/step - loss: 0.4317 - accuracy: 0.8024 - val_loss: 0.4116 - val_accuracy: 0.8155
# Epoch 25/100
# 10000/10000 [==============================] - 75s 8ms/step - loss: 0.4309 - accuracy: 0.8024 - val_loss: 0.4337 - val_accuracy: 0.7986
# Epoch 26/100
# 10000/10000 [==============================] - 75s 8ms/step - loss: 0.4287 - accuracy: 0.8023 - val_loss: 0.4275 - val_accuracy: 0.8105
# Epoch 27/100
# 10000/10000 [==============================] - 77s 8ms/step - loss: 0.4235 - accuracy: 0.8065 - val_loss: 0.3547 - val_accuracy: 0.8417
# Epoch 28/100
# 10000/10000 [==============================] - 76s 8ms/step - loss: 0.4279 - accuracy: 0.8037 - val_loss: 0.4423 - val_accuracy: 0.7920
# Epoch 29/100
# 10000/10000 [==============================] - 79s 8ms/step - loss: 0.4254 - accuracy: 0.8032 - val_loss: 0.3763 - val_accuracy: 0.8306
# Epoch 30/100
# 10000/10000 [==============================] - 78s 8ms/step - loss: 0.4244 - accuracy: 0.8044 - val_loss: 0.4408 - val_accuracy: 0.7969
# Epoch 31/100
# 10000/10000 [==============================] - 80s 8ms/step - loss: 0.4301 - accuracy: 0.8023 - val_loss: 0.4184 - val_accuracy: 0.8080
# Epoch 32/100
# 10000/10000 [==============================] - 78s 8ms/step - loss: 0.4264 - accuracy: 0.8027 - val_loss: 0.4300 - val_accuracy: 0.8004
# Epoch 33/100
# 10000/10000 [==============================] - 81s 8ms/step - loss: 0.4245 - accuracy: 0.8047 - val_loss: 0.4086 - val_accuracy: 0.8145
# Epoch 34/100
# 10000/10000 [==============================] - 80s 8ms/step - loss: 0.4268 - accuracy: 0.8041 - val_loss: 0.4093 - val_accuracy: 0.8173
# Epoch 35/100
# 10000/10000 [==============================] - 82s 8ms/step - loss: 0.4170 - accuracy: 0.8098 - val_loss: 0.3998 - val_accuracy: 0.8297
# Epoch 36/100
# 10000/10000 [==============================] - 81s 8ms/step - loss: 0.4205 - accuracy: 0.8077 - val_loss: 0.4006 - val_accuracy: 0.8165
# Epoch 37/100
# 10000/10000 [==============================] - 83s 8ms/step - loss: 0.4177 - accuracy: 0.8098 - val_loss: 0.4853 - val_accuracy: 0.7698
# Epoch 38/100
# 10000/10000 [==============================] - 83s 8ms/step - loss: 0.4226 - accuracy: 0.8062 - val_loss: 0.4693 - val_accuracy: 0.7854
# Epoch 39/100
# 10000/10000 [==============================] - 82s 8ms/step - loss: 0.4193 - accuracy: 0.8085 - val_loss: 0.4568 - val_accuracy: 0.7811
# Epoch 40/100
# 10000/10000 [==============================] - 83s 8ms/step - loss: 0.4126 - accuracy: 0.8112 - val_loss: 0.4261 - val_accuracy: 0.8057
# Epoch 41/100
# 10000/10000 [==============================] - 90s 9ms/step - loss: 0.4183 - accuracy: 0.8107 - val_loss: 0.4562 - val_accuracy: 0.7849
# Epoch 42/100
# 10000/10000 [==============================] - 85s 8ms/step - loss: 0.4192 - accuracy: 0.8087 - val_loss: 0.3879 - val_accuracy: 0.8268
# Epoch 43/100
# 10000/10000 [==============================] - 85s 8ms/step - loss: 0.4328 - accuracy: 0.7997 - val_loss: 0.4310 - val_accuracy: 0.8012
# Epoch 44/100
# 10000/10000 [==============================] - 85s 8ms/step - loss: 0.4194 - accuracy: 0.8094 - val_loss: 0.4296 - val_accuracy: 0.7969
# Epoch 45/100
# 10000/10000 [==============================] - 85s 9ms/step - loss: 0.4091 - accuracy: 0.8128 - val_loss: 0.4749 - val_accuracy: 0.7818
# Epoch 46/100
# 10000/10000 [==============================] - 85s 8ms/step - loss: 0.4241 - accuracy: 0.8061 - val_loss: 0.3991 - val_accuracy: 0.8179
# Epoch 47/100
# 10000/10000 [==============================] - 86s 9ms/step - loss: 0.4317 - accuracy: 0.8025 - val_loss: 0.4078 - val_accuracy: 0.8227
# Epoch 48/100
# 10000/10000 [==============================] - 84s 8ms/step - loss: 0.4309 - accuracy: 0.8018 - val_loss: 0.4247 - val_accuracy: 0.8117
# Epoch 49/100
# 10000/10000 [==============================] - 83s 8ms/step - loss: 0.4283 - accuracy: 0.8033 - val_loss: 0.5090 - val_accuracy: 0.7660
# Epoch 50/100
# 10000/10000 [==============================] - 86s 9ms/step - loss: 0.4251 - accuracy: 0.8047 - val_loss: 0.4540 - val_accuracy: 0.7908
# Epoch 51/100
# 10000/10000 [==============================] - 86s 9ms/step - loss: 0.4297 - accuracy: 0.8022 - val_loss: 0.4350 - val_accuracy: 0.8065
# Epoch 52/100
# 10000/10000 [==============================] - 84s 8ms/step - loss: 0.4263 - accuracy: 0.8033 - val_loss: 0.4539 - val_accuracy: 0.7877
# Epoch 53/100
# 10000/10000 [==============================] - 84s 8ms/step - loss: 0.4179 - accuracy: 0.8116 - val_loss: 0.3959 - val_accuracy: 0.8256
# Epoch 54/100
# 10000/10000 [==============================] - 85s 9ms/step - loss: 0.4166 - accuracy: 0.8091 - val_loss: 0.5247 - val_accuracy: 0.7517
# Epoch 55/100
# 10000/10000 [==============================] - 85s 9ms/step - loss: 0.4176 - accuracy: 0.8102 - val_loss: 0.4967 - val_accuracy: 0.7743
# Epoch 56/100
# 10000/10000 [==============================] - 83s 8ms/step - loss: 0.4164 - accuracy: 0.8109 - val_loss: 0.4298 - val_accuracy: 0.7958
# Epoch 57/100
# 10000/10000 [==============================] - 83s 8ms/step - loss: 0.4247 - accuracy: 0.8048 - val_loss: 0.4513 - val_accuracy: 0.7983
# Epoch 58/100
# 10000/10000 [==============================] - 83s 8ms/step - loss: 0.4135 - accuracy: 0.8124 - val_loss: 0.4719 - val_accuracy: 0.7860
# Epoch 59/100
# 10000/10000 [==============================] - 82s 8ms/step - loss: 0.4245 - accuracy: 0.8054 - val_loss: 0.4343 - val_accuracy: 0.7986
# Epoch 60/100
# 10000/10000 [==============================] - 84s 8ms/step - loss: 0.4263 - accuracy: 0.8045 - val_loss: 0.3709 - val_accuracy: 0.8357
# Epoch 61/100
# 10000/10000 [==============================] - 84s 8ms/step - loss: 0.4342 - accuracy: 0.7993 - val_loss: 0.4299 - val_accuracy: 0.7957
# Epoch 62/100
# 10000/10000 [==============================] - 82s 8ms/step - loss: 0.4195 - accuracy: 0.8087 - val_loss: 0.4646 - val_accuracy: 0.7855
# Epoch 63/100
# 10000/10000 [==============================] - 84s 8ms/step - loss: 0.4216 - accuracy: 0.8076 - val_loss: 0.4933 - val_accuracy: 0.7950
# Epoch 64/100
# 10000/10000 [==============================] - 84s 8ms/step - loss: 0.4327 - accuracy: 0.7994 - val_loss: 0.4425 - val_accuracy: 0.7921
# Epoch 65/100
# 10000/10000 [==============================] - 83s 8ms/step - loss: 0.4325 - accuracy: 0.8012 - val_loss: 0.3535 - val_accuracy: 0.8453
# Epoch 66/100
# 10000/10000 [==============================] - 82s 8ms/step - loss: 0.4309 - accuracy: 0.8022 - val_loss: 0.5094 - val_accuracy: 0.7545
# Epoch 67/100
# 10000/10000 [==============================] - 84s 8ms/step - loss: 0.4216 - accuracy: 0.8069 - val_loss: 0.4160 - val_accuracy: 0.8070
# Epoch 68/100
# 10000/10000 [==============================] - 84s 8ms/step - loss: 0.4179 - accuracy: 0.8092 - val_loss: 0.4536 - val_accuracy: 0.7929
# Epoch 69/100
# 10000/10000 [==============================] - 84s 8ms/step - loss: 0.4145 - accuracy: 0.8111 - val_loss: 0.3939 - val_accuracy: 0.8203
# Epoch 70/100
# 10000/10000 [==============================] - 82s 8ms/step - loss: 0.4119 - accuracy: 0.8125 - val_loss: 0.4178 - val_accuracy: 0.8084
# Epoch 71/100
# 10000/10000 [==============================] - 83s 8ms/step - loss: 0.4150 - accuracy: 0.8126 - val_loss: 0.5976 - val_accuracy: 0.7322
# Epoch 72/100
# 10000/10000 [==============================] - 83s 8ms/step - loss: 0.4207 - accuracy: 0.8081 - val_loss: 0.4298 - val_accuracy: 0.8094
# Epoch 73/100
# 10000/10000 [==============================] - 84s 8ms/step - loss: 0.4261 - accuracy: 0.8056 - val_loss: 0.3633 - val_accuracy: 0.8427
# Epoch 74/100
# 10000/10000 [==============================] - 82s 8ms/step - loss: 0.4190 - accuracy: 0.8072 - val_loss: 0.4701 - val_accuracy: 0.7883
# Epoch 75/100
# 10000/10000 [==============================] - 82s 8ms/step - loss: 0.4112 - accuracy: 0.8138 - val_loss: 0.4918 - val_accuracy: 0.7936
# Epoch 76/100
# 10000/10000 [==============================] - 82s 8ms/step - loss: 0.4130 - accuracy: 0.8133 - val_loss: 0.4384 - val_accuracy: 0.8082
# Epoch 77/100
# 10000/10000 [==============================] - 82s 8ms/step - loss: 0.4111 - accuracy: 0.8122 - val_loss: 0.4746 - val_accuracy: 0.7645
# Epoch 78/100
# 10000/10000 [==============================] - 82s 8ms/step - loss: 0.4144 - accuracy: 0.8109 - val_loss: 0.4639 - val_accuracy: 0.7862
# Epoch 79/100
# 10000/10000 [==============================] - 81s 8ms/step - loss: 0.4055 - accuracy: 0.8165 - val_loss: 0.4947 - val_accuracy: 0.7684
# Epoch 80/100
# 10000/10000 [==============================] - 81s 8ms/step - loss: 0.4033 - accuracy: 0.8182 - val_loss: 0.4135 - val_accuracy: 0.8120
# Epoch 81/100
# 10000/10000 [==============================] - 81s 8ms/step - loss: 0.4054 - accuracy: 0.8167 - val_loss: 0.5223 - val_accuracy: 0.7534
# Epoch 82/100
# 10000/10000 [==============================] - 81s 8ms/step - loss: 0.4027 - accuracy: 0.8172 - val_loss: 0.4656 - val_accuracy: 0.7928
# Epoch 83/100
# 10000/10000 [==============================] - 81s 8ms/step - loss: 0.4082 - accuracy: 0.8162 - val_loss: 0.4176 - val_accuracy: 0.8107
# Epoch 84/100
# 10000/10000 [==============================] - 81s 8ms/step - loss: 0.4045 - accuracy: 0.8173 - val_loss: 0.3740 - val_accuracy: 0.8286
# Epoch 85/100
# 10000/10000 [==============================] - 80s 8ms/step - loss: 0.4028 - accuracy: 0.8189 - val_loss: 0.4456 - val_accuracy: 0.8055
# Epoch 86/100
# 10000/10000 [==============================] - 80s 8ms/step - loss: 0.4061 - accuracy: 0.8175 - val_loss: 0.4195 - val_accuracy: 0.8188
# Epoch 87/100
# 10000/10000 [==============================] - 80s 8ms/step - loss: 0.4058 - accuracy: 0.8174 - val_loss: 0.4658 - val_accuracy: 0.8019
# Epoch 88/100
# 10000/10000 [==============================] - 78s 8ms/step - loss: 0.4067 - accuracy: 0.8177 - val_loss: 0.4575 - val_accuracy: 0.7908
# Epoch 89/100
# 10000/10000 [==============================] - 79s 8ms/step - loss: 0.4112 - accuracy: 0.8156 - val_loss: 0.4729 - val_accuracy: 0.7797
# Epoch 90/100
# 10000/10000 [==============================] - 79s 8ms/step - loss: 0.4108 - accuracy: 0.8145 - val_loss: 0.3594 - val_accuracy: 0.8399
# Epoch 91/100
# 10000/10000 [==============================] - 79s 8ms/step - loss: 0.4106 - accuracy: 0.8130 - val_loss: 0.3957 - val_accuracy: 0.8364
# Epoch 92/100
# 10000/10000 [==============================] - 79s 8ms/step - loss: 0.4192 - accuracy: 0.8094 - val_loss: 0.5368 - val_accuracy: 0.7577
# Epoch 93/100
# 10000/10000 [==============================] - 79s 8ms/step - loss: 0.4116 - accuracy: 0.8128 - val_loss: 0.5985 - val_accuracy: 0.7329
# Epoch 94/100
# 10000/10000 [==============================] - 79s 8ms/step - loss: 0.4146 - accuracy: 0.8125 - val_loss: 0.4205 - val_accuracy: 0.8188
# Epoch 95/100
# 10000/10000 [==============================] - 78s 8ms/step - loss: 0.4000 - accuracy: 0.8191 - val_loss: 0.4330 - val_accuracy: 0.8063
# Epoch 96/100
# 10000/10000 [==============================] - 80s 8ms/step - loss: 0.4234 - accuracy: 0.8066 - val_loss: 0.4168 - val_accuracy: 0.8105
# Epoch 97/100
# 10000/10000 [==============================] - 77s 8ms/step - loss: 0.4202 - accuracy: 0.8073 - val_loss: 0.3814 - val_accuracy: 0.8226
# Epoch 98/100
# 10000/10000 [==============================] - 79s 8ms/step - loss: 0.4074 - accuracy: 0.8157 - val_loss: 0.3733 - val_accuracy: 0.8321
# Epoch 99/100
# 10000/10000 [==============================] - 78s 8ms/step - loss: 0.4040 - accuracy: 0.8172 - val_loss: 0.3463 - val_accuracy: 0.8528
# Epoch 100/100
# 10000/10000 [==============================] - 77s 8ms/step - loss: 0.4088 - accuracy: 0.8154 - val_loss: 0.4040 - val_accuracy: 0.8231

# %%
# Save model
if not model_history_loaded or (force_model_train and not no_save) or not no_save:
    save_model_history(classifier, history, model_name)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./models/basic_tanh_model_cifake/model\assets
# INFO:tensorflow:Assets written to: ./models/basic_tanh_model_cifake/model\assets

# %%
# Plot performance curves
plot_performance_curves(history, model_name)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
